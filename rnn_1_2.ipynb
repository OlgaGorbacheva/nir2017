# %% [markdown]
# # Эксперименты с RNN.
# ## 1. Простая LSTM сеть. Из 1 слоя.

# %%
# %matplotlib inline
import numpy as np
import tensorflow as tf
from matplotlib import pyplot as plt
from generate_sin import SampleGenerator

# %% [markdown]
# ## Experiment 1.2
# Пробуем tanh нелинейность в lstm.
#
# Цель: просто запустить и проверить, что что-то работает.
#
# Функция потерь: l2-loss
#
# Увеличим размер выборки
#
# Все остальное оставим прежним

# %%
x_left = 0
x_right = 4 * np.pi
param_bounds=[[0.1, 1.9],[0., 2.],[0.1, 1.9],[0, 2.]]

# %%
sample_size=200
batch_size=50
set_size=300000
test_percent=0.05
train_size = int(set_size * (1 - test_percent))
cv_fold=10
params_shape=4

# %%
gen = SampleGenerator(x_left, x_right, param_bounds)
X_train, Y_train, X_test, Y_test = gen(sample_size, set_size, test_percent, 'simple_rnn')
plt.plot(Y_train[0])
print X_train.shape, Y_train.shape, X_test.shape, Y_test.shape
# Out:
# (285000, 200, 4) (285000, 200) (15000, 200, 4) (15000, 200)

# %%
data = tf.placeholder(tf.float32, [batch_size, sample_size, params_shape])
target = tf.placeholder(tf.float32, [batch_size, sample_size])

# %%
cell = tf.contrib.rnn.BasicLSTMCell(sample_size, state_is_tuple=True)
val, state = tf.nn.dynamic_rnn(cell, data, dtype=tf.float32)
val = tf.transpose(val, [1, 0, 2])
last = tf.gather(val, int(val.get_shape()[0]) - 1)
weight = tf.Variable(tf.truncated_normal([sample_size, int(target.get_shape()[1])]))
bias = tf.Variable(tf.constant(0.1, shape=[target.get_shape()[1]]))

# %%
prediction = tf.matmul(last, weight) + bias
print prediction.shape
# Out:
# (50, 200)

# %%
loss = tf.reduce_mean(tf.sqrt(tf.reduce_sum(tf.square(tf.subtract(prediction, target)), axis=1)))
print loss.shape
# Out:
# ()

# %%
#optimizer = tf.train.AdamOptimizer()
optimizer = tf.train.AdagradOptimizer(0.01)
minimize = optimizer.minimize(loss)

# %%
def plot_test(i=0):
    ptr = 0
    inp, out = X_test[ptr:ptr+batch_size], Y_test[ptr:ptr+batch_size]
    ptr+=batch_size
    p, l = sess.run([prediction, loss],{data: inp, target: out})
    print '\tLoss', l
    plt.plot(Y_test[i])
    plt.plot(p[i])

def plot_train(i=0):
    ptr = 0
    inp, out = X_train[ptr:ptr+batch_size], Y_train[ptr:ptr+batch_size]
    ptr+=batch_size
    p, l = sess.run([prediction, loss],{data: inp, target: out})
    print '\tLoss', l
    plt.plot(Y_train[i])
    plt.plot(p[i])

# %%
init_op = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init_op)

# %%
plot_train()
# Out:
# 	Loss 27.4565

# %%
ptr = 3510 * batch_size
loss_mass = []
for j in range(train_size // batch_size):
    inp, out = X_train[ptr:ptr+batch_size], Y_train[ptr:ptr+batch_size]
    ptr+=batch_size
    _, l = sess.run([minimize, loss],{data: inp, target: out})
    loss_mass.append(l)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-a0d4a085a6fc> in <module>()
#       4     inp, out = X_train[ptr:ptr+batch_size], Y_train[ptr:ptr+batch_size]
#       5     ptr+=batch_size
# ----> 6     _, l = sess.run([minimize, loss],{data: inp, target: out})
#       7     loss_mass.append(l)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     776     try:
#     777       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 778                          run_metadata_ptr)
#     779       if run_metadata:
#     780         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     959                 'Cannot feed value of shape %r for Tensor %r, '
#     960                 'which has shape %r'
# --> 961                 % (np_val.shape, subfeed_t.name, str(subfeed_t.get_shape())))
#     962           if not self.graph.is_feedable(subfeed_t):
#     963             raise ValueError('Tensor %s may not be fed.' % subfeed_t)
#
# ValueError: Cannot feed value of shape (0, 200, 4) for Tensor u'Placeholder:0', which has shape '(50, 200, 4)'

# %%
plt.plot(loss_mass)

# %%
plot_train()
# Out:
# 	Loss 2.30693

# %%
plot_test(17)
# Out:
# 	Loss 1.86015

# %% [markdown]
# Выводы:
#     -
#     -
#     -
